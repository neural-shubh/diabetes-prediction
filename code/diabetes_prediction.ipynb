# %%
from google.colab import drive
drive.mount('/content/drive')
# df.to_csv('/content/drive/MyDrive/diabetes.csv', index=False)
# Out:
# Mounted at /content/drive

# %% [markdown]
# Loading dataset[link text](https://)

# %%
import numpy as np
import pandas as pd
import io
df = pd.read_csv('/content/drive/MyDrive/diabetes_data_upload.csv')
df.head()
# Out:
#    Age Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0   40   Male       No        Yes                 No      Yes         No
# 1   58   Male       No         No                 No      Yes         No
# 2   41   Male      Yes         No                 No      Yes        Yes
# 3   45   Male       No         No                Yes      Yes        Yes
# 4   60   Male      Yes        Yes                Yes      Yes        Yes
#
#   Genital thrush visual blurring Itching Irritability delayed healing  \
# 0             No              No     Yes           No             Yes
# 1             No             Yes      No           No              No
# 2             No              No     Yes           No             Yes
# 3            Yes              No     Yes           No             Yes
# 4             No             Yes     Yes          Yes             Yes
#
#   partial paresis muscle stiffness Alopecia Obesity     class
# ...

# %%
cols = ['Age', 'Gender', 'Polyuria', 'Polydipsia', 'sudden weight loss', 'weakness', 'Polyphagia', 'Genital thrush', 'visual blurring', 'Itching', 'Irritability', 'delayed healing', 'partial paresis', 'muscle stiffness', 'Alopecia', 'Obesity', 'class']
df.columns = cols
df.isnull()
# Out:
#        Age  Gender  Polyuria  Polydipsia  sudden weight loss  weakness  \
# 0    False   False     False       False               False     False
# 1    False   False     False       False               False     False
# 2    False   False     False       False               False     False
# 3    False   False     False       False               False     False
# 4    False   False     False       False               False     False
# ..     ...     ...       ...         ...                 ...       ...
# 515  False   False     False       False               False     False
# 516  False   False     False       False               False     False
# 517  False   False     False       False               False     False
# 518  False   False     False       False               False     False
# 519  False   False     False       False               False     False
#
#      Polyphagia  Genital thrush  visual blurring  Itching  Irritability  \
# ...

# %%
df['class'].unique()
# Out:
# array(['Positive', 'Negative'], dtype=object)

# %%
df.isnull()
# Out:
#        Age  Gender  Polyuria  Polydipsia  sudden weight loss  weakness  \
# 0    False   False     False       False               False     False
# 1    False   False     False       False               False     False
# 2    False   False     False       False               False     False
# 3    False   False     False       False               False     False
# 4    False   False     False       False               False     False
# ..     ...     ...       ...         ...                 ...       ...
# 515  False   False     False       False               False     False
# 516  False   False     False       False               False     False
# 517  False   False     False       False               False     False
# 518  False   False     False       False               False     False
# 519  False   False     False       False               False     False
#
#      Polyphagia  Genital thrush  visual blurring  Itching  Irritability  \
# ...

# %%
df.isnull().sum()
# Out:
# Age                   0
# Gender                0
# Polyuria              0
# Polydipsia            0
# sudden weight loss    0
# weakness              0
# Polyphagia            0
# Genital thrush        0
# visual blurring       0
# Itching               0
# Irritability          0
# delayed healing       0
# partial paresis       0
# muscle stiffness      0
# Alopecia              0
# Obesity               0
# class                 0
# dtype: int64

# %%
# x = df.iloc[:,:1]
# y = df.iloc[:,:1]

# %% [markdown]
# Train & Test

# %%
from sklearn.model_selection import train_test_split
x = df.drop('class', axis=1)
y = df['class']
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=14)

# %%
x_train
# Out:
#      Age  Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 352   67    Male      Yes         No                 No      Yes        Yes
# 303   58  Female      Yes         No                Yes       No        Yes
# 361   38  Female      Yes        Yes                Yes      Yes        Yes
# 409   50  Female       No         No                 No      Yes         No
# 189   69  Female      Yes         No                Yes      Yes        Yes
# ..   ...     ...      ...        ...                ...      ...        ...
# 358   55    Male      Yes        Yes                Yes      Yes         No
# 327   47    Male       No         No                 No       No         No
# 406   56    Male       No         No                Yes      Yes        Yes
# 268   45  Female       No         No                 No       No        Yes
# 344   61  Female      Yes         No                 No       No        Yes
#
# ...

# %%
x_test
# Out:
#      Age  Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 140   47    Male      Yes        Yes                 No       No         No
# 481   53    Male       No         No                 No      Yes        Yes
# 148   44    Male       No        Yes                 No       No         No
# 404   47    Male       No         No                 No       No         No
# 230   35    Male       No         No                Yes      Yes         No
# ..   ...     ...      ...        ...                ...      ...        ...
# 479   30    Male       No         No                 No       No         No
# 413   42    Male       No         No                 No       No         No
# 418   43  Female      Yes        Yes                Yes      Yes        Yes
# 424   43    Male      Yes        Yes                Yes      Yes         No
# 264   38  Female      Yes        Yes                Yes      Yes        Yes
#
# ...

# %% [markdown]
# Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd

# Identify categorical columns in the original x DataFrame
categorical_cols = x.select_dtypes(include='object').columns

# Apply one-hot encoding to x_train and x_test
x_train_encoded = pd.get_dummies(x_train, columns=categorical_cols, drop_first=True)
x_test_encoded = pd.get_dummies(x_test, columns=categorical_cols, drop_first=True)

# Initialize StandardScaler
sd = StandardScaler()

# Fit the scaler on the training data and transform both training and testing data
x_train_scaled = sd.fit_transform(x_train_encoded)
x_test_scaled = sd.transform(x_test_encoded)

# Convert the scaled arrays back to DataFrames, preserving column names and index
x_train = pd.DataFrame(x_train_scaled, columns=x_train_encoded.columns, index=x_train_encoded.index)
x_test = pd.DataFrame(x_test_scaled, columns=x_test_encoded.columns, index=x_test_encoded.index)

x_train.head()
# Out:
#           Age  Gender_Male  Polyuria_Yes  Polydipsia_Yes  \
# 352  1.573446     0.782562      1.024334       -0.881917
# 303  0.838818    -1.277854      1.024334       -0.881917
# 361 -0.793689    -1.277854      1.024334        1.133893
# 409  0.185815    -1.277854     -0.976244       -0.881917
# 189  1.736697    -1.277854      1.024334       -0.881917
#
#      sudden weight loss_Yes  weakness_Yes  Polyphagia_Yes  Genital thrush_Yes  \
# 352               -0.818952      0.847944        1.090630           -0.510496
# 303                1.221072     -1.179324        1.090630           -0.510496
# 361                1.221072      0.847944        1.090630           -0.510496
# 409               -0.818952      0.847944       -0.916901           -0.510496
# 189                1.221072      0.847944        1.090630            1.958880
#
#      visual blurring_Yes  Itching_Yes  Irritability_Yes  delayed healing_Yes  \
# ...

# %% [markdown]
# Loading Algorithms

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
models = {
    'LogisticRegression': LogisticRegression(),
    'SVC' : SVC(),
    'DecisionTreeClassifier' : DecisionTreeClassifier(),
    'RandomForestClassifier' : RandomForestClassifier()
}

# %%
result = {}

# %% [markdown]
# Evaluation

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
for name,model in models.items():
  model.fit(x_train,y_train)
  y_pred  = model.predict(x_test)
  acc = accuracy_score(y_test,y_pred)
  result[name] = acc

# %%
print(f"\n{name}:")
print(f"Accuracy:{acc}")
print(classification_report(y_test,y_pred))
# Out:
# RandomForestClassifier:
# Accuracy:0.9807692307692307
#               precision    recall  f1-score   support
#
#     Negative       0.94      1.00      0.97        34
#     Positive       1.00      0.97      0.99        70
#
#     accuracy                           0.98       104
#    macro avg       0.97      0.99      0.98       104
# weighted avg       0.98      0.98      0.98       104

# %% [markdown]
# **Model** **Comparison**

# %%
print("\n Final Comparison")
for model,acc in result.items():
  print(f"{model} Accuracy:{acc:.4f}")
# Out:
#  Final Comparison
# LogisticRegression Accuracy:0.8750
# SVC Accuracy:0.9231
# DecisionTreeClassifier Accuracy:0.9712
# RandomForestClassifier Accuracy:0.9808

# %% [markdown]
# Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
# Hyperparameter tuning for Random Forest

rf = RandomForestClassifier()

param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 5, 10],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2]
}

grid = GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

# Train with tuning
grid.fit(x_train, y_train)

# Best model
best_rf = grid.best_estimator_

# Predictions
y_pred = best_rf.predict(x_test)

# Evaluation
from sklearn.metrics import accuracy_score

print("Best Parameters:", grid.best_params_)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Best Parameters: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# Accuracy: 0.9903846153846154

# %% [markdown]
# **Visualization**

# %%
import matplotlib.pyplot as plt

names = list(result.keys())
values = list(result.values())

plt.bar(names, values)
plt.title("Model Comparison")
plt.ylabel("Accuracy")
plt.xticks(rotation=30)
plt.show()

# %%
import joblib

# Save the best model (use whichever performed best)
joblib.dump(best_rf, 'diabetes_model.pkl')  # change model name if needed
joblib.dump(sd, 'scaler.pkl')

# Download to your local machine
from google.colab import files
files.download('diabetes_model.pkl')
files.download('scaler.pkl')

# %%
import joblib

joblib.dump(best_rf, 'diabetes_model.pkl')

from google.colab import files
files.download('diabetes_model.pkl')

# %%
# !git clone https://github.com/neural-shubh/diabetes-prediction.git
# %cd diabetes-prediction
# Out:
# Cloning into 'diabetes-prediction'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 13 (delta 1), reused 2 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (13/13), 43.50 KiB | 4.35 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
# /content/diabetes-prediction

# %%
import shutil, os

shutil.unpack_archive('/content/diabetes-app.zip', 'temp/')

# Copy files
shutil.copy('temp/diabetes-app/app.py', '.')
shutil.copy('temp/diabetes-app/requirements.txt', '.')
shutil.copy('temp/diabetes-app/Procfile', '.')
shutil.copy('temp/diabetes-app/render.yaml', '.')
shutil.copy('temp/diabetes-app/diabetes_model.pkl', '.')
shutil.copy('temp/diabetes-app/scaler.pkl', '.')

os.makedirs('templates', exist_ok=True)
shutil.copy('temp/diabetes-app/templates/index.html', 'templates/')
# Out:
# 'templates/index.html'

# %%
# !pip install skl2onnx onnx

from skl2onnx import convert_sklearn
from skl2onnx.common.data_types import FloatTensorType
import joblib

model = joblib.load('diabetes_model.pkl')
scaler = joblib.load('scaler.pkl')

# Convert scaler
initial_type_scaler = [('float_input', FloatTensorType([None, 16]))]
onnx_scaler = convert_sklearn(scaler, initial_types=initial_type_scaler)

# Convert model
initial_type_model = [('float_input', FloatTensorType([None, 16]))]
onnx_model = convert_sklearn(model, initial_types=initial_type_model)

# Save both
with open('scaler.onnx', 'wb') as f:
    f.write(onnx_scaler.SerializeToString())

with open('diabetes_model.onnx', 'wb') as f:
    f.write(onnx_model.SerializeToString())

from google.colab import files
files.download('scaler.onnx')
files.download('diabetes_model.onnx')

print('Done!')
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.2/317.2 kB 12.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 22.4 MB/s eta 0:00:00
# ...
# Done!

# %%
import os, shutil

# Clone fresh
os.chdir('/content')
# !git clone https://github.com/neural-shubh/diabetes-prediction.git
os.chdir('/content/diabetes-prediction')

# Create docs folder and move files
os.makedirs('docs/models', exist_ok=True)
shutil.copy('templates/index.html', 'docs/index.html')
shutil.copy('scaler.onnx', 'docs/models/scaler.onnx')
shutil.copy('diabetes_model.onnx', 'docs/models/diabetes_model.onnx')

# Push
# !git add .
# !git commit -m "move app to docs folder"
# !git push https://neural-shubh:YOUR_TOKEN@github.com/neural-shubh/diabetes-prediction.git
# Out:
# fatal: destination path 'diabetes-prediction' already exists and is not an empty directory.
# [main 918ef70] move app to docs folder
#  5 files changed, 532 insertions(+)
#  create mode 100644 diabetes_model.onnx
#  create mode 100644 docs/index.html
#  create mode 100644 docs/models/diabetes_model.onnx
#  create mode 100644 docs/models/scaler.onnx
#  create mode 100644 scaler.onnx
# remote: Invalid username or token. Password authentication is not supported for Git operations.
# fatal: Authentication failed for 'https://github.com/neural-shubh/diabetes-prediction.git/'

# %%
import os, shutil

os.chdir('/content')

# Remove old clone if exists
# !rm -rf diabetes-prediction

# Clone fresh
# !git clone https://github.com/neural-shubh/diabetes-prediction.git
os.chdir('/content/diabetes-prediction')

# Check what files are here
# !ls
# Out:
# Cloning into 'diabetes-prediction'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 27 (delta 2), reused 16 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (27/27), 255.62 KiB | 1.34 MiB/s, done.
# Resolving deltas: 100% (2/2), done.
# app.py			   Procfile	requirements.txt  templates
# diabetes_model.pkl	   README.md	scaler.pkl
# diabetes_prediction.ipynb  render.yaml	temp

# %%
# !pip install skl2onnx onnx
import os, shutil
from skl2onnx import convert_sklearn
from skl2onnx.common.data_types import FloatTensorType
import joblib

# Ensure ONNX files are created in the current directory if they are missing
# This logic is adapted from cell y2mx5OG8iej5
if not os.path.exists('scaler.onnx') or not os.path.exists('diabetes_model.onnx'):
    print("Re-creating ONNX models as they were not found.")
    # Load the original models
    model = joblib.load('diabetes_model.pkl')
    scaler = joblib.load('scaler.pkl')

    # Convert scaler
    initial_type_scaler = [('float_input', FloatTensorType([None, 16]))]
    onnx_scaler = convert_sklearn(scaler, initial_types=initial_type_scaler)

    # Convert model
    initial_type_model = [('float_input', FloatTensorType([None, 16]))]
    onnx_model = convert_sklearn(model, initial_types=initial_type_model)

    # Save both ONNX files
    with open('scaler.onnx', 'wb') as f:
        f.write(onnx_scaler.SerializeToString())

    with open('diabetes_model.onnx', 'wb') as f:
        f.write(onnx_model.SerializeToString())
    print("ONNX models re-created successfully.")

# Create docs folder
os.makedirs('docs/models', exist_ok=True)

# Copy files
shutil.copy('templates/index.html', 'docs/index.html')
shutil.copy('scaler.onnx', 'docs/models/scaler.onnx')
shutil.copy('diabetes_model.onnx', 'docs/models/diabetes_model.onnx')

# !ls docs/
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.2/317.2 kB 10.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 96.2 MB/s eta 0:00:00
# ...
# Re-creating ONNX models as they were not found.
# ONNX models re-created successfully.
# index.html  models
